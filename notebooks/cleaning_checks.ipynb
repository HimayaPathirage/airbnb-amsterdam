# %%
import sys
sys.path.append('../src')
from clean import clean_listings

df_clean = clean_listings()
flagged = df_clean[df_clean['price_outlier_flag'] == True]
print(flagged[['id', 'name', 'price_clean']].to_string())
# Out:
# Loaded listings: 10480 rows, 79 columns
# Price cleaned. Outliers flagged: 7
#
# Date parsing check:
#    host_since host_since_parsed
# 0  2010-03-23        2010-03-23
# 1  2010-05-13        2010-05-13
# 2  2010-05-13        2010-05-13
# 3  2010-08-08        2010-08-08
# 4  2010-09-01        2010-09-01
#
# Unparseable dates per column:
#   last_scraped: 0 unparseable (out of 10480 non-null originals)
#   first_review: 1097 unparseable (out of 9383 non-null originals)
#   last_review: 1097 unparseable (out of 9383 non-null originals)
#   host_since: 3 unparseable (out of 10477 non-null originals)
#
# Property type grouping:
# property_type_grouped
# Entire place      8214
# Private room      1371
# Hotel room         418
# Houseboat/Boat     392
# Other               30
# Shared room         29
# Room in other       26
# Name: count, dtype: int64
#
# Columns after dropping unreliable ones: 85
# Missing flags: beds=4576, bathrooms=4548, price=4606
#
# ...

# %%
import sys
sys.path.append('../src')
from clean import clean_listings

df_clean = clean_listings()

# Check 1: confirm first_review nulls match the no-review listings
print("first_review null count (raw):", df_clean['first_review'].isnull().sum())
print("Matches 1,097 no-review listings?", df_clean['first_review'].isnull().sum() == 1097)

# Check 2: find the 3 unparseable host_since rows
bad_host_since = df_clean[df_clean['host_since'].notna() & df_clean['host_since_parsed'].isna()]
print(bad_host_since[['id', 'host_since']])
# Out:
# Loaded listings: 10480 rows, 79 columns
# Price cleaned. Outliers flagged: 7
#
# Date parsing check:
#    host_since host_since_parsed
# 0  2010-03-23        2010-03-23
# 1  2010-05-13        2010-05-13
# 2  2010-05-13        2010-05-13
# 3  2010-08-08        2010-08-08
# 4  2010-09-01        2010-09-01
#
# Unparseable dates per column:
#   last_scraped: 0 unparseable (out of 10480 non-null originals)
#   first_review: 1097 unparseable (out of 9383 non-null originals)
#   last_review: 1097 unparseable (out of 9383 non-null originals)
#   host_since: 3 unparseable (out of 10477 non-null originals)
#
# Property type grouping:
# property_type_grouped
# Entire place      8214
# Private room      1371
# Hotel room         418
# Houseboat/Boat     392
# Other               30
# Shared room         29
# Room in other       26
# Name: count, dtype: int64
#
# Columns after dropping unreliable ones: 85
# Missing flags: beds=4576, bathrooms=4548, price=4606
#
# ...

# %%
print(df_clean['host_since'].isnull().sum())
print(df_clean['host_since_parsed'].isnull().sum())
# Out:
# 3
# 3

# %%
import sys
sys.path.append('../src')
from clean import clean_listings

df_clean = clean_listings()

print(df_clean[df_clean['property_type_grouped'] == 'Other']['property_type'].value_counts())
print()
print(df_clean[df_clean['property_type_grouped'] == 'Hotel room']['property_type'].value_counts())
# Out:
# Loaded listings: 10480 rows, 79 columns
# Price cleaned. Outliers flagged: 7
#
# Date parsing check:
#    host_since host_since_parsed
# 0  2010-03-23        2010-03-23
# 1  2010-05-13        2010-05-13
# 2  2010-05-13        2010-05-13
# 3  2010-08-08        2010-08-08
# 4  2010-09-01        2010-09-01
#
# Unparseable dates per column:
#   last_scraped: 0 unparseable (out of 10480 non-null originals)
#   first_review: 1097 unparseable (out of 9383 non-null originals)
#   last_review: 1097 unparseable (out of 9383 non-null originals)
#   host_since: 3 unparseable (out of 10477 non-null originals)
#
# Property type grouping:
# property_type_grouped
# Entire place      8214
# Private room      1371
# Hotel room         418
# Houseboat/Boat     392
# Other               30
# Shared room         29
# Room in other       26
# Name: count, dtype: int64
#
# Columns after dropping unreliable ones: 85
# Missing flags: beds=4576, bathrooms=4548, price=4606
#
# ...

# %%
import sys
sys.path.append('../src')
from clean import clean_listings

df_clean = clean_listings()

print("Negative prices:", (df_clean['price_clean'] < 0).sum())
print("Accommodates <= 0:", (df_clean['accommodates'] <= 0).sum())
print("Minimum nights <= 0:", (df_clean['minimum_nights'] <= 0).sum())
print("Host_since in the future:", (df_clean['host_since_parsed'] > df_clean['last_scraped_parsed']).sum())
# Out:
# Loaded listings: 10480 rows, 79 columns
# Price cleaned. Outliers flagged: 7
#
# Date parsing check:
#    host_since host_since_parsed
# 0  2010-03-23        2010-03-23
# 1  2010-05-13        2010-05-13
# 2  2010-05-13        2010-05-13
# 3  2010-08-08        2010-08-08
# 4  2010-09-01        2010-09-01
#
# Unparseable dates per column:
#   last_scraped: 0 unparseable (out of 10480 non-null originals)
#   first_review: 1097 unparseable (out of 9383 non-null originals)
#   last_review: 1097 unparseable (out of 9383 non-null originals)
#   host_since: 3 unparseable (out of 10477 non-null originals)
#
# Property type grouping:
# property_type_grouped
# Entire place      8214
# Private room      1371
# Hotel room         418
# Houseboat/Boat     392
# Other               30
# Shared room         29
# Room in other       26
# Name: count, dtype: int64
#
# Columns after dropping unreliable ones: 85
# Missing flags: beds=4576, bathrooms=4548, price=4606
#
# ...

# %%
print(df_clean[['latitude', 'longitude']].head(10))
print(df_clean['latitude'].round(5).equals(df_clean['latitude']))
# Out:
#    latitude  longitude
# 0  52.38761    4.89188
# 1  52.36775    4.89092
# 2  52.36584    4.89111
# 3  52.37168    4.91471
# 4  52.32781    4.87680
# 5  52.38028    4.89089
# 6  52.36938    4.92958
# 7  52.37559    4.83857
# 8  52.36959    4.88423
# 9  52.35559    5.00320
# True

# %%
import sys
sys.path.append('../src')
from enrich import enrich_listings

df = enrich_listings()
print(df['price_per_bedroom'].dtype)
print(df['price_per_bedroom'].head(10))
# Out:
# Loaded listings: 10480 rows, 79 columns
# Price cleaned. Outliers flagged: 7
#
# Date parsing check:
#    host_since host_since_parsed
# 0  2010-03-23        2010-03-23
# 1  2010-05-13        2010-05-13
# 2  2010-05-13        2010-05-13
# 3  2010-08-08        2010-08-08
# 4  2010-09-01        2010-09-01
#
# Unparseable dates per column:
#   last_scraped: 0 unparseable (out of 10480 non-null originals)
#   first_review: 1097 unparseable (out of 9383 non-null originals)
#   last_review: 1097 unparseable (out of 9383 non-null originals)
#   host_since: 3 unparseable (out of 10477 non-null originals)
#
# Property type grouping:
# property_type_grouped
# Entire place      8214
# Private room      1371
# Hotel room         418
# Houseboat/Boat     392
# Other               30
# Shared room         29
# Room in other       26
# Name: count, dtype: int64
#
# Columns after dropping unreliable ones: 85
# Missing flags: beds=4576, bathrooms=4548, price=4606
#
# ...

# %%
import sys
sys.path.append('../src')
from enrich import enrich_listings

df = enrich_listings()

extreme_freq = df.sort_values('review_frequency', ascending=False).head(5)
print(extreme_freq[['id', 'host_tenure_years', 'review_count_computed', 'review_frequency']])

extreme_ppb = df[df['price_outlier_flag'] == True][['id', 'price_clean', 'bedrooms', 'price_per_bedroom']]
print(extreme_ppb)
# Out:
# Loaded listings: 10480 rows, 79 columns
# Price cleaned. Outliers flagged: 7
#
# Date parsing check:
#    host_since host_since_parsed
# 0  2010-03-23        2010-03-23
# 1  2010-05-13        2010-05-13
# 2  2010-05-13        2010-05-13
# 3  2010-08-08        2010-08-08
# 4  2010-09-01        2010-09-01
#
# Unparseable dates per column:
#   last_scraped: 0 unparseable (out of 10480 non-null originals)
#   first_review: 1097 unparseable (out of 9383 non-null originals)
#   last_review: 1097 unparseable (out of 9383 non-null originals)
#   host_since: 3 unparseable (out of 10477 non-null originals)
#
# Property type grouping:
# property_type_grouped
# Entire place      8214
# Private room      1371
# Hotel room         418
# Houseboat/Boat     392
# Other               30
# Shared room         29
# Room in other       26
# Name: count, dtype: int64
#
# Columns after dropping unreliable ones: 85
# Missing flags: beds=4576, bathrooms=4548, price=4606
#
# ...

# %%
extreme_freq = df.sort_values('review_frequency', ascending=False).head(5)
print(extreme_freq[['id', 'host_tenure_years', 'review_count_computed', 'review_frequency']].to_string())
# Out:
#                         id  host_tenure_years  review_count_computed  review_frequency
# 4229              50383849           4.243669                 5097.0       1201.083387
# 10020  1445482496485405601           0.235455                  181.0        768.723837
# 3945              45045046           5.059548                 3187.0        629.898133
# 3062              32485135           6.573580                 3726.0        566.814452
# 1629              15258535           1.100616                  585.0        531.520522
